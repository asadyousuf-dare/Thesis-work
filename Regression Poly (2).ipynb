# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt

# %%
X = pd.read_excel('C:/Users/Engineer Asad yousuf/Desktop/Data/LearningVariables.xlsx')
y = pd.read_excel('C:/Users/Engineer Asad yousuf/Desktop/DataLearningY.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-1d6105493eee> in <module>
#       1 X = pd.read_excel('C:/Users/Engineer Asad yousuf/Desktop/Data/LearningVariables.xlsx')
# ----> 2 y = pd.read_excel('C:/Users/Engineer Asad yousuf/Desktop/DataLearningY.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
display(X)

display(y)
# Out:
#       Unnamed: 0      fc20     fy20    cover    depth      area
# 0            NaN  25.96875  255.025  0.02903  0.28332  0.000181
# 1            NaN  16.93375  100.675  0.06461  0.24388  0.000520
# 2            NaN  32.92375  918.775  0.02899  0.18692  0.000251
# 3            NaN  23.59625  537.175  0.05823  0.14756  0.000319
# 4            NaN  63.76625  506.125  0.05349  0.20852  0.000223
# ...          ...       ...      ...      ...      ...       ...
# 1995         NaN  45.04625  326.575  0.06181  0.26540  0.000534
# 1996         NaN  51.41625  340.525  0.05461  0.29724  0.000349
# 1997         NaN  73.61375  487.225  0.03665  0.27276  0.000134
# 1998         NaN  71.20875  660.925  0.04467  0.18876  0.000391
# 1999         NaN  18.39625  785.575  0.05543  0.25428  0.000468
#
# [2000 rows x 6 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25,random_state=357)

X = pd.read_excel('C:/Users/svire/Desktop/ZYousouf/LearningVariables.xlsx')
y = pd.read_excel('C:/Users/svire/Desktop/ZYousouf/LearningY.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e265420c4ea8> in <module>
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25,random_state=357)
#       2
#       3 X = pd.read_excel('C:/Users/svire/Desktop/ZYousouf/LearningVariables.xlsx')
#       4 y = pd.read_excel('C:/Users/svire/Desktop/ZYousouf/LearningY.xlsx')
#
# NameError: name 'x' is not defined

# %%
for i in x.columns:
    for j in y.columns:
        plt.scatter(x[i],y[j])
        plt.xlabel(i)
        plt.ylabel(j)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89a9d89103dd> in <module>
# ----> 1 for i in x.columns:
#       2     for j in y.columns:
#       3         plt.scatter(x[i],y[j])
#       4         plt.xlabel(i)
#       5         plt.ylabel(j)
#
# NameError: name 'x' is not defined

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
predicted = regr.predict(X_test)



print("Predicted Values: \n",predicted)
# Out:
# Predicted Values:
#  [[ 5.67673209e+04]
#  [ 2.19696974e+04]
#  [ 4.48936763e+04]
#  [ 4.28145895e+04]
#  [ 2.12799095e+04]
#  [ 4.67904160e+04]
#  [ 2.61627008e+04]
#  [ 2.42139231e+04]
#  [ 5.07315979e+04]
#  [ 5.17907962e+04]
#  [ 2.20111962e+04]
#  [ 2.78590602e+04]
#  [ 3.65133752e+04]
#  [ 4.15535160e+03]
#  [ 3.39649420e+04]
#  [ 3.73984899e+04]
#  [ 3.42570082e+04]
#  [ 4.79611126e+04]
#  [ 6.20150307e+04]
#  [ 7.66266618e+03]
#  [ 5.39427831e+04]
#  [-3.33530576e+03]
#  [ 4.64450338e+04]
#  [ 4.39387942e+04]
#  [ 5.22998993e+04]
#  [ 3.16974625e+04]
#  [ 2.64411444e+04]
#  [ 2.09052444e+04]
#  [ 4.35408682e+04]
#  [-1.67032793e+03]
#  [ 8.22553561e+04]
#  [ 3.58098149e+04]
#  [ 1.60374446e+04]
#  [ 3.57720979e+04]
#  [ 5.12129089e+04]
#  [ 3.88814673e+04]
#  [ 2.95846393e+03]
#  [ 2.66295317e+04]
#  [-2.44637369e+03]
#  [ 2.51598827e+04]
#  [ 7.07730009e+04]
#  [ 5.62690318e+04]
#  [ 2.55789150e+04]
#  [ 4.14110731e+04]
#  [ 4.36403792e+04]
#  [ 3.37981187e+04]
# ...

# %%
#R-squared (R2) is a statistical measure that represents the proportion of the variance for a dependent variable 
#that's explained by an independent variable or variables in a regression

r2_score(y_test, predicted)
# Out:
# 0.8810092918893355

# %%
C = [0.1,1,10,100,10000]
solver = ['liblinear']
degree= [1,2,3,4,5]
param_grid = {'classify_lr__C':C,'classify_lr__solver':solver,'poly_features__degree':degree}
clf = GridSearchCV(regr, param_grid)

clf
# Out:
# GridSearchCV(estimator=LinearRegression(),
#              param_grid={'classify_lr__C': [0.1, 1, 10, 100, 10000],
#                          'classify_lr__solver': ['liblinear'],
#                          'poly_features__degree': [1, 2, 3, 4, 5]})

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)

X_train_poly = poly_reg.fit_transform(X_train)

pol_reg = LinearRegression()

pol_reg.fit(X_train_poly, y_train)

X_test_poly = poly_reg.fit_transform(X_test)

y_predict = pol_reg.predict(X_test_poly)
r2_score(y_test,y_predict)
# Out:
# 0.9952532952555744
