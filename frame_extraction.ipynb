# %% [markdown]
# <a href="https://colab.research.google.com/github/asadyousuf-dare/Thesis-work/blob/main/frame_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import glob
from google.colab import drive

# %%
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
folders = glob.glob('/content/drive/MyDrive/cv/video/NoFire')

# %%
videonames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.mp4'):
      videonames_list.append(f)
      print(f)
# Out:
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid14.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid4.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid1.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid10.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid11.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid12.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid16.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid15.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid13.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid7.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid6.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid3.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid5.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid2.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid9.mp4
# /content/drive/MyDrive/cv/video/NoFire/NoFireVid8.mp4

# %%
print('There are {} videos in Folder'.format(len(videonames_list)))
# Out:
# There are 16 videos in Folder

# %%
count = 0
for i in range(0,len(videonames_list)):
  video_data = videonames_list[i]
  video = cv2.VideoCapture(video_data)
  success = True
  while success:
    success,image = video.read()
    names = '/content/drive/MyDrive/cv/video/NoFire/name'+str(count)+'.jpg'
    if success == True:
      cv2.imwrite(names,image)
      print('Frame {} Extracted Successfully'.format(count))
      count+=1
    else:
      i = i+1  
    i = i+1
  print('\n\n\nVideo {} Extracted Successfully\n\n\n'.format(video_data))
# Out:
# Streaming output truncated to the last 5000 lines.
# Frame 1845 Extracted Successfully
# Frame 1846 Extracted Successfully
# Frame 1847 Extracted Successfully
# Frame 1848 Extracted Successfully
# Frame 1849 Extracted Successfully
# Frame 1850 Extracted Successfully
# Frame 1851 Extracted Successfully
# Frame 1852 Extracted Successfully
# Frame 1853 Extracted Successfully
# Frame 1854 Extracted Successfully
# Frame 1855 Extracted Successfully
# Frame 1856 Extracted Successfully
# Frame 1857 Extracted Successfully
# Frame 1858 Extracted Successfully
# Frame 1859 Extracted Successfully
# Frame 1860 Extracted Successfully
# Frame 1861 Extracted Successfully
# Frame 1862 Extracted Successfully
# Frame 1863 Extracted Successfully
# Frame 1864 Extracted Successfully
# Frame 1865 Extracted Successfully
# Frame 1866 Extracted Successfully
# Frame 1867 Extracted Successfully
# Frame 1868 Extracted Successfully
# Frame 1869 Extracted Successfully
# Frame 1870 Extracted Successfully
# ...
